# %%
from rl.reps.experiments.scripts.reps_pendulum import MyExperiment
# %load_ext plot_work
# %set_experiment_class MyExperiment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0f537d826f00> in <module>
# ----> 1 from rl.reps.experiments.scripts.reps_pendulum import MyExperiment
#       2 get_ipython().run_line_magic('load_ext', 'plot_work')
#       3 get_ipython().run_line_magic('set_experiment_class', 'MyExperiment')
#
# ModuleNotFoundError: No module named 'rl'

# %%
# %cd /home/hany/PhdThesis/playground/rl/reps/experiments
# Out:
# /home/hany/PhdThesis/playground/rl/reps/experiments

# %%
# %load_experiment config/reps_pendulum.yml -e reps_pendulum
# %plot_results mean_2std rwrd

# %%
experiments
# Out:
# [{'name': 'reps_pendulum',
#   'repetitions': 3,
#   'iterations': 2,
#   'path': 'data/reps_pendulum',
#   'params': {'n_samples': 5000,
#    'n_iter': 1,
#    'n_rollouts': 25,
#    'n_steps': 200,
#    'n_keep': 0,
#    'kl_bound': 0.1,
#    'discount': 0.98,
#    'vreg': 1e-06,
#    'preg': 1e-06,
#    'cov0': 8.0,
#    'n_vfeat': 75,
#    'n_pfeat': 75,
#    'band': [0.5, 0.5, 4.0]},
#   '_config_path': 'data/',
#   'log_path': 'data/reps_pendulum/log'}]
