# %%
from scripts.reps_pendulum import MyExperiment
# %load_ext plot_work
# %set_experiment_class MyExperiment
# Out:
# The plot_work extension is already loaded. To reload it, use:
#   %reload_ext plot_work

# %%
# %cd /home/hany/mount/pycharm/playground/rl/examples/reps/experiments/config
# Out:
# /home/hany/mount/pycharm/playground/rl/examples/reps/experiments/config

# %%
# %load_experiment reps_pendulum.yml -e reps_pendulum
# %plot_results mean_2std rwrd_0

# %%
experiments
# Out:
# [{'name': 'reps_pendulum',
#   'repetitions': 25,
#   'iterations': 25,
#   'path': '../data/reps_pendulum',
#   'params': {'n_samples': 3000,
#    'n_keep': 0,
#    'n_rollouts': 25,
#    'n_steps': 250,
#    'kl_bound': 0.1,
#    'discount': 0.99,
#    'vreg': 1e-12,
#    'preg': 1e-12,
#    'cov0': 16.0,
#    'n_vfeat': 75,
#    'n_pfeat': 75,
#    'band': [0.5, 0.5, 4.0],
#    'mult': 0.5},
#   '_config_path': '../data/',
#   'log_path': '../data/reps_pendulum/log'}]
